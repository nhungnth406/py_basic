# %%
# 1/ df1, df2, df3, df4 giống nhau, cách tạo khác nhau 

import pandas as pd

# Tạo Dataframe từ list:
?????
print('df1:\n', df1,'\n')

# Tạo Dataframe từ Dictionary of List:
?????
print('df2:\n', df2,'\n')

# Tạo Dataframe từ List of Dicts:
?????
print('df3:\n', df3,'\n')

#  Tạo Data frame từ Dict of Series
?????
print('df4:\n', df4,'\n')
# Out:
# df1:
#       Price  Quantity
# VNM  12000      1560
# TCB  14500      2350
# MSN  13200      1890
# HSG  15700      1678

# %%
# 2/ 

import pandas as pd

?????
print('df:\n', df,'\n')

print('Thêm cột PE từ Series:','\n') 
?????
print(df,'\n')

print('Hiện cột Quantity:\n')
?????

print('Hiện cột Price, PE:\n')
?????

print('Xóa cột Price (không dùng del):\n')
?????
print(df)
# Out:
# df:
#       Price  Quantity
# VNM  12000      1560
# TCB  14500      2350
# MSN  13200      1890
# HSG  15700      1678
#
# Thêm cột PE từ Series:
#
#      Price  Quantity    PE
# VNM  12000      1560  2.75
# TCB  14500      2350  3.83
# MSN  13200      1890  5.64
# HSG  15700      1678  4.23
#
# Hiện cột Quantity:
#
# VNM    1560
# TCB    2350
# MSN    1890
# HSG    1678
# Name: Quantity, dtype: int64
#
# Hiện cột Price, PE:
#
#      Price    PE
# VNM  12000  2.75
# TCB  14500  3.83
# MSN  13200  5.64
# HSG  15700  4.23
#
# Xóa cột Price (không dùng del):
#
#      Quantity    PE
# VNM      1560  2.75
# TCB      2350  3.83
# MSN      1890  5.64
# HSG      1678  4.23

# %%
# 3/

import pandas as pd

?????
print('df:\n', df,'\n')

print("Xem thông tin TCB (dùng Label):\n")
?????

print("Xem thông tin TCB (dùng index):\n")
?????

print("Xem thông tin TCB, HSG (dùng Label):\n")
?????

print("Xem thông tin TCB, HSG (dùng index):\n")
?????

print("Xem thông tin VNM, TCB, MSN (dùng Label, slicing):\n")
?????

print("Xem thông tin VNM, TCB, MSN (dùng Index, slicing):\n")
?????
# Out:
# df:
#       Price  Quantity
# VNM  12000      1560
# TCB  14500      2350
# MSN  13200      1890
# HSG  15700      1678
#
# Xem thông tin TCB (dùng Label):
#
# Price       14500
# Quantity     2350
# Name: TCB, dtype: int64
#
# Xem thông tin TCB (dùng index):
#
# Price       14500
# Quantity     2350
# Name: TCB, dtype: int64
#
# Xem thông tin TCB, HSG (dùng Label):
#
#      Price  Quantity
# TCB  14500      2350
# HSG  15700      1678
#
# Xem thông tin TCB, HSG (dùng index):
#
#      Price  Quantity
# TCB  14500      2350
# HSG  15700      1678
#
# Xem thông tin VNM, TCB, MSN (dùng Label, slicing):
#
#      Price  Quantity
# VNM  12000      1560
# TCB  14500      2350
# MSN  13200      1890
#
# Xem thông tin VNM, TCB, MSN (dùng Index, slicing):
#
#      Price  Quantity
# VNM  12000      1560
# TCB  14500      2350
# MSN  13200      1890

# %%
# 4/

import pandas as pd

?????
print('df:\n', df,'\n')

print('Thêm 2 mã VHM, CSG:\n')
?????
print(df,'\n')

print('Xóa mã ACB:\n')
?????
print(df,'\n')
# Out:
# df:
#       Price  Quantity
# VNM  12000      1560
# TCB  14500      2350
# MSN  13200      1890
# ACB  15700      1678
#
# Thêm 2 mã VHM, CSG:
#
#      Price  Quantity
# VNM  12000      1560
# TCB  14500      2350
# MSN  13200      1890
# ACB  15700      1678
# VHM  16340       890
# CSG  13800      1235
#
# Xóa mã ACB:
#
#      Price  Quantity
# VNM  12000      1560
# TCB  14500      2350
# MSN  13200      1890
# VHM  16340       890
# CSG  13800      1235

# %%
# 5/
import pandas as pd

?????
print('df:\n', df,'\n')

print('Xem Price, PE của TCB, ACB, CSG (dùng Label):\n')
?????

print('Xem Price, PE của TCB, ACB, CSG (dùng Index):\n')
?????

print('Xem thông tin của MSN, ACB, VHM (dùng Label, slice):\n')
?????

print('Xem thông tin của MSN, ACB, VHM (dùng Index, slice):\n')
?????

print('Mã nào có PE > 4.5:\n')
?????

print('Xem Price các mã (Attribute Access):\n')
?????

print('Xem PE các mã (Use of Notations):\n')
?????
# Out:
# df:
#       Price  Quantity    PE
# VNM  12000      1560  2.34
# TCB  14500      2350  5.43
# MSN  13200      1890  4.56
# ACB  15700      1678  3.27
# VHM  16340       890  6.12
# CSG  13800      1235  4.35
#
# Xem Price, PE của TCB, ACB, CSG (dùng Label):
#
#      Price    PE
# TCB  14500  5.43
# ACB  15700  3.27
# CSG  13800  4.35
#
# Xem Price, PE của TCB, ACB, CSG (dùng Index):
#
#      Price    PE
# TCB  14500  5.43
# ACB  15700  3.27
# CSG  13800  4.35
#
# Xem thông tin của MSN, ACB, VHM (dùng Label, slice):
#
#      Price  Quantity    PE
# MSN  13200      1890  4.56
# ACB  15700      1678  3.27
# VHM  16340       890  6.12
#
# Xem thông tin của MSN, ACB, VHM (dùng Index, slice):
#
#      Price  Quantity    PE
# MSN  13200      1890  4.56
# ACB  15700      1678  3.27
# VHM  16340       890  6.12
#
# Mã nào có PE > 4.5:
#
# VNM    False
# TCB     True
# MSN     True
# ACB    False
# VHM     True
# CSG    False
# Name: PE, dtype: bool
#
# Xem Price các mã (Attribute Access):
#
# VNM    12000
# TCB    14500
# MSN    13200
# ACB    15700
# VHM    16340
# CSG    13800
# Name: Price, dtype: int64
#
# Xem PE các mã (Use of Notations):
#
# VNM    2.34
# TCB    5.43
# MSN    4.56
# ACB    3.27
# VHM    6.12
# CSG    4.35
# Name: PE, dtype: float64

# %%
# 6/

import pandas as pd

?????
print('df:\n', df,'\n')

print('Shape của dữ liệu:', ?????,'\n')

print('Kích thước của dữ liệu:', ?????,'\n')

print('Số chiều của dữ liệu:', ?????,'\n')

print('Danh sách các the row axis labels, column axis labels:\n')
?????

print('Kiểu dữ liệu của các cột:\n')
?????

print('Hoán đổi Dòng <-> Cột:\n')
?????

print('Xem giá trị:\n')
?????

print('Xem 3 mã đầu tiên:\n')
?????

print('Xem 3 mã cuối cùng:\n')
?????

print('Thông tin về df:\n')
?????
# Out:
# df:
#       Price  Quantity    PE
# VNM  12000      1560  2.34
# TCB  14500      2350  5.43
# MSN  13200      1890  4.56
# ACB  15700      1678  3.27
# VHM  16340       890  6.12
# CSG  13800      1235  4.35
#
# Shape của dữ liệu: (6, 3)
#
# Kích thước của dữ liệu: 18
#
# Số chiều của dữ liệu: 2
#
# Danh sách các the row axis labels, column axis labels:
#
# [Index(['VNM', 'TCB', 'MSN', 'ACB', 'VHM', 'CSG'], dtype='object'), Index(['Price', 'Quantity', 'PE'], dtype='object')]
#
# Kiểu dữ liệu của các cột:
#
# Price         int64
# Quantity      int64
# PE          float64
# dtype: object
#
# Hoán đổi Dòng <-> Cột:
#
#                VNM       TCB       MSN       ACB       VHM       CSG
# Price     12000.00  14500.00  13200.00  15700.00  16340.00  13800.00
# Quantity   1560.00   2350.00   1890.00   1678.00    890.00   1235.00
# PE            2.34      5.43      4.56      3.27      6.12      4.35
#
# Xem giá trị:
#
# [['VNM' 12000 1560 2.34]
#  ['TCB' 14500 2350 5.43]
#  ['MSN' 13200 1890 4.56]
#  ['ACB' 15700 1678 3.27]
#  ['VHM' 16340 890 6.12]
#  ['CSG' 13800 1235 4.35]]
#
# Xem 3 mã đầu tiên:
#
#      Price  Quantity    PE
# VNM  12000      1560  2.34
# TCB  14500      2350  5.43
# MSN  13200      1890  4.56
#
# Xem 3 mã cuối cùng:
#
#      Price  Quantity    PE
# ACB  15700      1678  3.27
# VHM  16340       890  6.12
# CSG  13800      1235  4.35
#
# Thông tin về df:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, VNM to CSG
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Price     6 non-null      int64
#  1   Quantity  6 non-null      int64
#  2   PE        6 non-null      float64
# dtypes: float64(1), int64(2)
# memory usage: 352.0+ bytes
# None

# %%
# 7/
import pandas as pd

?????

print('df:\n', df,'\n')

print('Xem Sort Index theo Group:\n')
?????

print('Xem Sort Index theo Code:\n')
?????

print('Xem Sort Index theo Code, chiều giảm dần:\n')
?????

print('Sort Index theo Group, kết quả ghi lại trong df:\n')
?????
print(df,'\n')

print('Sort Index theo Cột, kết quả ghi lại trong df:\n')
?????
print(df,'\n')

print('Xem Sort theo PE, sau đó theo Bid Price, theo thuật toán quicksort:\n')
?????
# Out:
# df:
#                Bid
#             Price Quantity    PE
# Group Code
# Food  VNM   12000     1560  2.34
# Bank  TCB   14500     2350  5.43
# Food  MSN   13200     1890  4.35
# Bank  ACB   15700     1678  3.27
#       VHM   16340      890  6.12
# Food  CSG   13800     1235  4.35
#
# Xem Sort Index theo Group:
#
#               Bid
#             Price Quantity    PE
# Group Code
# Bank  ACB   15700     1678  3.27
#       TCB   14500     2350  5.43
#       VHM   16340      890  6.12
# Food  CSG   13800     1235  4.35
#       MSN   13200     1890  4.35
#       VNM   12000     1560  2.34
#
# Xem Sort Index theo Code:
#
#               Bid
#             Price Quantity    PE
# Group Code
# Bank  ACB   15700     1678  3.27
# Food  CSG   13800     1235  4.35
#       MSN   13200     1890  4.35
# Bank  TCB   14500     2350  5.43
#       VHM   16340      890  6.12
# Food  VNM   12000     1560  2.34
#
# Xem Sort Index theo Code, chiều giảm dần:
#
#               Bid
#             Price Quantity    PE
# Group Code
# Food  VNM   12000     1560  2.34
# Bank  VHM   16340      890  6.12
#       TCB   14500     2350  5.43
# Food  MSN   13200     1890  4.35
#       CSG   13800     1235  4.35
# Bank  ACB   15700     1678  3.27
#
# Sort Index theo Group, kết quả ghi lại trong df:
#
#               Bid
#             Price Quantity    PE
# Group Code
# Bank  ACB   15700     1678  3.27
#       TCB   14500     2350  5.43
#       VHM   16340      890  6.12
# Food  CSG   13800     1235  4.35
#       MSN   13200     1890  4.35
#       VNM   12000     1560  2.34
#
# Sort Index theo Cột, kết quả ghi lại trong df:
#
#                     Bid
#               PE  Price Quantity
# Group Code
# Bank  ACB   3.27  15700     1678
#       TCB   5.43  14500     2350
#       VHM   6.12  16340      890
# Food  CSG   4.35  13800     1235
#       MSN   4.35  13200     1890
#       VNM   2.34  12000     1560
#
# Xem Sort theo PE, sau đó theo Bid Price, theo thuật toán quicksort:
#
#                     Bid
#               PE  Price Quantity
# Group Code
# Food  VNM   2.34  12000     1560
# Bank  ACB   3.27  15700     1678
# Food  MSN   4.35  13200     1890
#       CSG   4.35  13800     1235
# Bank  TCB   5.43  14500     2350
#       VHM   6.12  16340      890

# %%
# 8/
import pandas as pd

?????
print('df:\n', df,'\n')

print('df gồm các cột có tên:\n')
?????
    
print('Giá trị ở mỗi cột như sau:\n')
?????
    
print('Thông tin của mỗi cổ phiếu như sau:\n')
?????
    
?????
# Out:
# df:
#       Price  Quantity    PE
# VNM  12000      1560  2.34
# TCB  14500      2350  5.43
# MSN  13200      1890  4.56
# ACB  15700      1678  3.27
# VHM  16340       890  6.12
# CSG  13800      1235  4.35
#
# df gồm các cột có tên:
#
# Price
# Quantity
# PE
# Giá trị ở mỗi cột như sau:
#
# Price
#
# VNM    12000
# TCB    14500
# MSN    13200
# ACB    15700
# VHM    16340
# CSG    13800
# Name: Price, dtype: int64
#
# Quantity
#
# VNM    1560
# TCB    2350
# MSN    1890
# ACB    1678
# VHM     890
# CSG    1235
# Name: Quantity, dtype: int64
#
# PE
#
# VNM    2.34
# TCB    5.43
# MSN    4.56
# ACB    3.27
# VHM    6.12
# CSG    4.35
# Name: PE, dtype: float64
#
# Thông tin của mỗi cổ phiếu như sau:
#
# VNM
#
# Price       12000.00
# Quantity     1560.00
# PE              2.34
# Name: VNM, dtype: float64
#
# TCB
#
# Price       14500.00
# Quantity     2350.00
# PE              5.43
# Name: TCB, dtype: float64
#
# MSN
#
# Price       13200.00
# Quantity     1890.00
# PE              4.56
# Name: MSN, dtype: float64
#
# ACB
#
# Price       15700.00
# Quantity     1678.00
# PE              3.27
# Name: ACB, dtype: float64
#
# VHM
#
# Price       16340.00
# Quantity      890.00
# PE              6.12
# Name: VHM, dtype: float64
#
# CSG
#
# Price       13800.00
# Quantity     1235.00
# PE              4.35
# Name: CSG, dtype: float64
#
# Pandas(Index='VNM', Price=12000, Quantity=1560, PE=2.34)
# Pandas(Index='TCB', Price=14500, Quantity=2350, PE=5.43)
# Pandas(Index='MSN', Price=13200, Quantity=1890, PE=4.56)
# Pandas(Index='ACB', Price=15700, Quantity=1678, PE=3.27)
# Pandas(Index='VHM', Price=16340, Quantity=890, PE=6.12)
# Pandas(Index='CSG', Price=13800, Quantity=1235, PE=4.35)

# %%
# 9/
import pandas as pd

?????
print('df:\n', df,'\n')

print('Tổng cột Quantity:', ?????,'\n')
print('Trung bình cộng cột Price:', ?????,'\n')
print('Một số thông tin thống kê:\n', ?????,'\n')
# Out:
# df:
#       Price  Quantity    PE
# VNM  12000      1560  2.34
# TCB  14500      2350  5.43
# MSN  13200      1890  4.56
# ACB  15700      1678  3.27
# VHM  16340       890  6.12
# CSG  13800      1235  4.35
#
# Tổng cột Quantity: 9603
#
# Trung bình cộng cột Price: 14256.666666666666
#
# Một số thông tin thống kê:
#                Price     Quantity        PE
# count      6.000000     6.000000  6.000000
# mean   14256.666667  1600.500000  4.345000
# std     1606.258593   508.253382  1.382009
# min    12000.000000   890.000000  2.340000
# 25%    13350.000000  1316.250000  3.540000
# 50%    14150.000000  1619.000000  4.455000
# 75%    15400.000000  1837.000000  5.212500
# max    16340.000000  2350.000000  6.120000

# %%
# 10/
import pandas as pd
import numpy as np

?????
print('df:\n', df,'\n')

print('Tính giá trung bình gia quyền (sum(prod(Price*Quantiy))/sum(Quantity)) (Cách 1: chỉ pandas):')
?????

print('Tính giá trung bình gia quyền (sum(prod(Price*Quantiy))/sum(Quantity)) (Cách 2: dùng numpy_ufunc):')
?????
# Out:
# df:
#       Price  Quantity    PE
# VNM  12000      1560  2.34
# TCB  14500      2350  5.43
# MSN  13200      1890  4.56
# ACB  15700      1678  3.27
# VHM  16340       890  6.12
# CSG  13800      1235  4.35
#
# Tính giá trung bình gia quyền (sum(prod(Price*Quantiy))/sum(Quantity)) (Cách 1: chỉ pandas):
# 14128.209934395501
#
# Tính giá trung bình gia quyền (sum(prod(Price*Quantiy))/sum(Quantity)) (Cách 2: dùng numpy_ufunc):
# 14128.209934395501
